# %% [markdown]
# # **Instalações e Bibliotecas**

# %%
# %%capture

# !pip install shap
# !pip install optuna

# %%
import pandas as pd
import numpy as np

from sklearn.impute import KNNImputer

# %% [markdown]
# # **Funções**

# %% [markdown]
# O arquivo 'functions_pred_cruzada' contém as funções que serão utilizadas para selecionar, pré-processar e treinar e validar os modelos de machine learning

# %%
# !gdown 1uVoArwRTJmvbyFLyFniwFvWGHMfiNIWO --quiet

from functions_pred_cruzada import *

# %% [markdown]
# # **Dados**

# %%
# Dados brutos com todos os tipos de câncer
# !gdown 1P19f3kA5_s4sv5Pg6D6UKwwQvZvaAnQT --quiet

df_geral = pd.read_csv('pacigeral.csv')
print(df_geral.shape)
df_geral.head(3)
# Out:
# Columns (35,36,73,74,75,78,89,90) have mixed types. Specify dtype option on import or set low_memory=False.
# (1134043, 100)
#    ESCOLARI  IDADE  SEXO UFNASC UFRESID     IBGE          CIDADE  CATEATEND  \
# 0         2    100     2     SP      SP  3550308       SAO PAULO          9
# 1         1    102     1     MG      MG  3133402       ITAPAGIPE          9
# 2         2    101     2     MG      SP  3543402  RIBEIRAO PRETO          9
#
#     DTCONSULT  CLINICA  ...  REC03 REC04  IBGEATEN   CIDO  \
# 0  2000-06-09        3  ...    NaN   NaN   3550308  80703
# 1  2002-04-29       24  ...    NaN   NaN   3505500  80903
# 2  2000-12-03       10  ...    NaN   NaN   3543402  80703
#
#                        DSCCIDO HABILIT  \
# 0  CARCINOMA ESCAMOCELULAR SOE       7
# 1    CARCINOMA BASOCELULAR SOE       7
# 2  CARCINOMA ESCAMOCELULAR SOE       7
#
#                                      HABIT11 HABILIT1 HABILIT2         CIDADEH
# 0  CACON com Servio de Oncologia Pedi trica        3        2       SÆo Paulo
# 1  CACON com Servio de Oncologia Pedi trica        3        2        Barretos
# 2  CACON com Servio de Oncologia Pedi trica        3        2  RibeirÆo Preto
#
# [3 rows x 100 columns]

# %% [markdown]
# **Tipos com maior incidência**

# %%
df_geral.TOPOGRUP.value_counts(normalize=True).head(15)
# Out:
# C44    0.229273
# C50    0.136342
# C61    0.103496
# C34    0.047272
# C53    0.046387
# C18    0.037844
# C42    0.037599
# C16    0.036821
# C20    0.028988
# C73    0.023747
# C77    0.018756
# C15    0.018305
# C67    0.017882
# C32    0.015979
# C64    0.015855
# Name: TOPOGRUP, dtype: float64

# %% [markdown]
# *   C44 - Pele 22,93%
# *   C50 - Mama 13,63%
# *   C61 - Próstata 10,35%
# *   C34 - Pulmão 4,73%
# *   C53 - Colo de Útero 4,64%
# *   C18 - Cólon 3,78%
# *   C42 - ?? 3,76%
# *   C16 - Estômago 3,68%
# *   C20 - Reto 2,90%
# *   C73 - Tiróide 2,37%
# *   C77 - ?? 1,88%
# *   C15 - Esôfago 1,83%
# *   C67 - Bexiga 1,79%
# *   C32 - Laringe 1,60%
# *   C64 - Rim 1,59%

# %% [markdown]
# ## **Sistema Digestório**

# %% [markdown]
# * Boca (C00, C01, C02, C03, C04, C05, C06)

# %%
boca = ['C00', 'C01', 'C02', 'C03', 'C04', 'C05', 'C06']

df_boca = data_prep(df_geral, boca)
print(df_boca.shape)
df_boca.head(3)
# Out:
# (25413, 30)
#        IDADE  SEXO     IBGE  CATEATEND  DIAGPREV  TOPO TOPOGRUP   EC TRATHOSP  \
# 0        100     2  3550308          9         2  C031      C03  IVA        B
# 29783     29     1  3507803          9         1  C001      C00   II        A
# 29784     28     1  3520905          9         1  C001      C00    I        A
#
#        NENHUM  ...  DIAGTRAT  ANODIAG  DRS  RRAS  IBGEATEN  HABILIT2  \
# 0           0  ...         0     2000   01     6   3550308         2
# 29783       0  ...         0     2005   13    13   3543402         2
# 29784       0  ...         0     2004   09    10   3525300         2
#
#        ULTIDIAG  ESCOLARI_preench  IBGE_idem_IBGEATEN  presenca_rec
# 0           171               2.0                   1             0
# 29783       482               3.0                   0             0
# 29784      5139               3.0                   0             0
#
# [3 rows x 30 columns]

# %%
df_boca = get_labels(df_boca)
df_boca.shape
# Out:
# (25413, 32)

# %% [markdown]
# * Orofaringe (C10)

# %%
oro = ['C10']

df_oro = data_prep(df_geral, oro)
print(df_oro.shape)
df_oro.head(3)
# Out:
# (5121, 30)
#        IDADE  SEXO     IBGE  CATEATEND  DIAGPREV  TOPO TOPOGRUP   EC TRATHOSP  \
# 30156     27     1  3550308          2         1  C102      C10  IVB        F
# 30159     20     2  3526902          2         2  C103      C10  IVC        F
# 30160     23     2  3503901          2         1  C108      C10    I        E
#
#        NENHUM  ...  DIAGTRAT  ANODIAG  DRS  RRAS  IBGEATEN  HABILIT2  \
# 30156       0  ...         2     2015   01     6   3550308         2
# 30159       0  ...         0     2014   10    14   3526902         1
# 30160       0  ...         0     2013   01     2   3550308         1
#
#        ULTIDIAG  ESCOLARI_preench  IBGE_idem_IBGEATEN  presenca_rec
# 30156      2423               3.0                   1             0
# 30159       731               2.0                   1             0
# 30160      2357               3.0                   0             0
#
# [3 rows x 30 columns]

# %%
df_oro = get_labels(df_oro)
df_oro.shape
# Out:
# (5121, 32)

# %% [markdown]
# * Esôfago (C15)

# %%
eso = ['C15']

df_eso = data_prep(df_geral, eso)
print(df_eso.shape)
df_eso.head(3)
# Out:
# (14379, 30)
#        IDADE  SEXO     IBGE  CATEATEND  DIAGPREV  TOPO TOPOGRUP    EC  \
# 30392     28     2  3549904          2         2  C150      C15    IV
# 30393     27     2  3509601          2         1  C150      C15  IIIC
# 30394     28     1  3550308          2         1  C152      C15   III
#
#       TRATHOSP  NENHUM  ...  DIAGTRAT  ANODIAG  DRS  RRAS  IBGEATEN  HABILIT2  \
# 30392        C       0  ...         2     2019   17    17   3549904         1
# 30393        F       0  ...         2     2018   07    16   3550308         2
# 30394        A       0  ...         0     2004   01     6   3550308         2
#
#        ULTIDIAG  ESCOLARI_preench  IBGE_idem_IBGEATEN  presenca_rec
# 30392       309               3.0                   1             0
# 30393       212               1.0                   0             0
# 30394       585               3.0                   1             0
#
# [3 rows x 30 columns]

# %%
df_eso = get_labels(df_eso)
df_eso.shape
# Out:
# (14379, 32)

# %% [markdown]
# * Estômago (C16)

# %%
esto = ['C16']

df_esto = data_prep(df_geral, esto)
print(df_esto.shape)
df_esto.head(3)
# Out:
# (29043, 30)
#        IDADE  SEXO     IBGE  CATEATEND  DIAGPREV  TOPO TOPOGRUP  EC TRATHOSP  \
# 30427     28     2  3518800          9         1  C160      C16  IV        C
# 30428     29     2  3550308          9         1  C160      C16  IV        J
# 30429     29     1  3557105          9         1  C160      C16  II        F
#
#        NENHUM  ...  DIAGTRAT  ANODIAG  DRS  RRAS  IBGEATEN  HABILIT2  \
# 30427       0  ...         0     2002   01     2   3550308         2
# 30428       1  ...        99     2003   01     6   3550308         2
# 30429       0  ...         0     2006   15    12   3550308         2
#
#        ULTIDIAG  ESCOLARI_preench  IBGE_idem_IBGEATEN  presenca_rec
# 30427       170               4.0                   0             0
# 30428        54               3.0                   1             0
# 30429       260               5.0                   0             1
#
# [3 rows x 30 columns]

# %%
df_esto = get_labels(df_esto)
df_esto.shape
# Out:
# (29043, 32)

# %% [markdown]
# * Intestino Delgado (C17)

# %%
delg = ['C17']

df_delg = data_prep(df_geral, delg)
print(df_delg.shape)
df_delg.head(3)
# Out:
# (1772, 30)
#        IDADE  SEXO     IBGE  CATEATEND  DIAGPREV  TOPO TOPOGRUP  EC TRATHOSP  \
# 30863     28     2  3550308          9         2  C170      C17   I        A
# 30865     22     1  3550308          2         1  C170      C17  IV        E
# 30866     25     1  3504107          2         2  C170      C17  IV        J
#
#        NENHUM  ...  DIAGTRAT  ANODIAG  DRS  RRAS  IBGEATEN  HABILIT2  \
# 30863       0  ...         0     2008   01     6   3550308         2
# 30865       0  ...         0     2005   01     6   3550308         2
# 30866       1  ...        99     2009   07    16   3550308         2
#
#        ULTIDIAG  ESCOLARI_preench  IBGE_idem_IBGEATEN  presenca_rec
# 30863      1028               3.0                   1             0
# 30865       109               1.0                   1             0
# 30866        91               4.0                   0             0
#
# [3 rows x 30 columns]

# %%
df_delg = get_labels(df_delg)
df_delg.shape
# Out:
# (1772, 32)

# %% [markdown]
# * Colorretal (C18, C19, C20)

# %%
colo = ['C18', 'C19', 'C20']

df_colo = data_prep(df_geral, colo)
print(df_colo.shape)
df_colo.head(3)
# Out:
# (60887, 30)
#        IDADE  SEXO     IBGE  CATEATEND  DIAGPREV  TOPO TOPOGRUP   EC TRATHOSP  \
# 30913     28     2  3548708          9         1  C180      C18  III        E
# 30914     26     2  3550308          9         1  C180      C18  III        A
# 30916     22     2  3503208          9         2  C180      C18   IV        C
#
#        NENHUM  ...  DIAGTRAT  ANODIAG  DRS  RRAS  IBGEATEN  HABILIT2  \
# 30913       0  ...         0     2003   01     1   3550308         1
# 30914       0  ...         0     2001   01     6   3550308         2
# 30916       0  ...         0     2001   03    13   3503208         1
#
#        ULTIDIAG  ESCOLARI_preench  IBGE_idem_IBGEATEN  presenca_rec
# 30913       415               3.0                   0             0
# 30914      2478               2.0                   1             0
# 30916       255               4.0                   1             0
#
# [3 rows x 30 columns]

# %%
df_colo = get_labels(df_colo)
df_colo.shape
# Out:
# (60887, 32)

# %% [markdown]
# * Ânus (C21)

# %%
anus = ['C21']

df_anus = data_prep(df_geral, anus)
print(df_anus.shape)
df_anus.head(3)
# Out:
# (2466, 30)
#        IDADE  SEXO     IBGE  CATEATEND  DIAGPREV  TOPO TOPOGRUP    EC  \
# 31830     29     1  3518800          9         2  C211      C21    IV
# 31832     23     1  3550308          9         1  C211      C21  IIIB
# 31834     28     1  3507753          9         2  C211      C21    II
#
#       TRATHOSP  NENHUM  ...  DIAGTRAT  ANODIAG  DRS  RRAS  IBGEATEN  HABILIT2  \
# 31830        G       0  ...         2     2008   01     2   3550308         2
# 31832        B       0  ...         2     2005   01     6   3550308         2
# 31834        B       0  ...         1     2010   02    12   3505500         2
#
#        ULTIDIAG  ESCOLARI_preench  IBGE_idem_IBGEATEN  presenca_rec
# 31830       672               3.0                   0             0
# 31832      1099               2.0                   1             0
# 31834       649               5.0                   0             0
#
# [3 rows x 30 columns]

# %%
df_anus = get_labels(df_anus)
df_anus.shape
# Out:
# (2466, 32)

# %%
# import plotly.graph_objects as go

# grup_ec = np.sort(df_boca.ECGRUP.unique())

# fig = go.Figure(data=[
#     go.Bar(name='Boca', x=grup_ec, y=df_boca.ECGRUP.value_counts(normalize=True).sort_index()*100,
#            text=df_boca.ECGRUP.value_counts(normalize=True).sort_index()*100),
#     go.Bar(name='Orofaringe', x=grup_ec, y=df_oro.ECGRUP.value_counts(normalize=True).sort_index()*100,
#            text=df_oro.ECGRUP.value_counts(normalize=True).sort_index()*100),
#     go.Bar(name='Esôfago', x=grup_ec, y=df_eso.ECGRUP.value_counts(normalize=True).sort_index()*100,
#            text=df_eso.ECGRUP.value_counts(normalize=True).sort_index()*100),
#     go.Bar(name='Estômago', x=grup_ec, y=df_esto.ECGRUP.value_counts(normalize=True).sort_index()*100,
#            text=df_esto.ECGRUP.value_counts(normalize=True).sort_index()*100),
#     go.Bar(name='Intestino Delgado', x=grup_ec, y=df_delg.ECGRUP.value_counts(normalize=True).sort_index()*100,
#            text=df_delg.ECGRUP.value_counts(normalize=True).sort_index()*100),
#     go.Bar(name='Colorretal', x=grup_ec, y=df_colo.ECGRUP.value_counts(normalize=True).sort_index()*100,
#            text=df_colo.ECGRUP.value_counts(normalize=True).sort_index()*100),
#     go.Bar(name='Ânus', x=grup_ec, y=df_anus.ECGRUP.value_counts(normalize=True).sort_index()*100,
#            text=df_anus.ECGRUP.value_counts(normalize=True).sort_index()*100)
# ])
# # Change the bar mode
# fig.update_layout(barmode='group', yaxis_title='% Pacientes',
#                   xaxis_title='Estadiamento Clínico')
# fig.update_traces(texttemplate='%{text:.3s}', textposition='outside')
# fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="08b55ec4-328c-436c-b05b-b34747a1c729" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08b55ec4-328c-436c-b05b-b34747a1c729")) {                    Plotly.newPlot(                        "08b55ec4-328c-436c-b05b-b34747a1c729",                        [{"name":"Boca","text":[17.412348010860583,14.173848030535552,15.826545468854523,52.587258489749345],"x":["I","II","III","IV"],"y":[17.412348010860583,14.173848030535552,15.826545468854523,52.587258489749345],"type":"bar","textposition":"outside","texttemplate":"%{text:.3s}"},{"name":"Orofaringe","text":[4.901386447959383,7.5571177504393665,15.38761960554579,72.15387619605545],"x":["I","II","III","IV"],"y":[4.901386447959383,7.5571177504393665,15.38761960554579,72.15387619605545],"type":"bar","textposition":"outside","texttemplate":"%{text:.3s}"},{"name":"Es\u00f4fago","text":[6.655539328186939,23.583002990472217,36.887127060296265,32.87433062104458],"x":["I","II","III","IV"],"y":[6.655539328186939,23.583002990472217,36.887127060296265,32.87433062104458],"type":"bar","textposition":"outside","texttemplate":"%{text:.3s}"},{"name":"Est\u00f4mago","text":[14.78841717453431,13.655614089453568,25.23843955514237,46.31752918086974],"x":["I","II","III","IV"],"y":[14.78841717453431,13.655614089453568,25.23843955514237,46.31752918086974],"type":"bar","textposition":"outside","texttemplate":"%{text:.3s}"},{"name":"Intestino Delgado","text":[19.5823927765237,20.146726862302483,27.257336343115124,33.01354401805869],"x":["I","II","III","IV"],"y":[19.5823927765237,20.146726862302483,27.257336343115124,33.01354401805869],"type":"bar","textposition":"outside","texttemplate":"%{text:.3s}"},{"name":"Colorretal","text":[13.329610590109548,29.0850263603068,31.420500270993806,26.16486277858985],"x":["I","II","III","IV"],"y":[13.329610590109548,29.0850263603068,31.420500270993806,26.16486277858985],"type":"bar","textposition":"outside","texttemplate":"%{text:.3s}"},{"name":"\u00c2nus","text":[9.813463098134632,37.145174371451745,41.078669910786694,11.962692619626926],"x":["I","II","III","IV"],"y":[9.813463098134632,37.145174371451745,41.078669910786694,11.962692619626926],"type":"bar","textposition":"outside","texttemplate":"%{text:.3s}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5 ...

# %%
df_boca.columns
# Out:
# Index(['IDADE', 'SEXO', 'IBGE', 'CATEATEND', 'DIAGPREV', 'TOPO', 'TOPOGRUP',
#        'EC', 'TRATHOSP', 'NENHUM', 'CIRURGIA', 'RADIO', 'QUIMIO', 'HORMONIO',
#        'TMO', 'IMUNO', 'OUTROS', 'CONSDIAG', 'TRATCONS', 'DIAGTRAT', 'ANODIAG',
#        'DRS', 'RRAS', 'IBGEATEN', 'HABILIT2', 'ESCOLARI_preench',
#        'IBGE_idem_IBGEATEN', 'presenca_rec', 'obito_geral', 'sobrevida_ano1',
#        'sobrevida_ano3', 'sobrevida_ano5'],
#       dtype='object')

# %%
dfs = [df_boca, df_oro, df_eso, df_esto, df_delg, df_colo, df_anus]
for df in dfs:
    print(df[~((df.obito_geral == 0) & (df.sobrevida_ano3 == 0))].sobrevida_ano3.value_counts(normalize=True).sort_index())
# Out:
# 0    0.593974
# 1    0.406026
# Name: sobrevida_ano3, dtype: float64
# 0    0.744509
# 1    0.255491
# Name: sobrevida_ano3, dtype: float64
# 0    0.869225
# 1    0.130775
# Name: sobrevida_ano3, dtype: float64
# 0    0.733289
# 1    0.266711
# Name: sobrevida_ano3, dtype: float64
# 0    0.55527
# 1    0.44473
# Name: sobrevida_ano3, dtype: float64
# 0    0.45493
# 1    0.54507
# Name: sobrevida_ano3, dtype: float64
# 0    0.465253
# 1    0.534747
# Name: sobrevida_ano3, dtype: float64

# %% [markdown]
# Salvando os dados no Drive

# %%
todos = ['C00', 'C01', 'C02', 'C03', 'C04', 'C05', 'C06', # Boca
         'C10',                                           # Orofaringe
         'C15',                                           # Esôfago
         'C16',                                           # Estômago
         'C17',                                           # Intestino Delgado
         'C18', 'C19', 'C20',                             # Colorretal
         'C21']                                           # Ânus

df_todos = data_prep(df_geral, todos)
df_todos = get_labels(df_todos)
df_todos.shape
# Out:
# (139081, 32)

# %%
# df_todos.to_csv('/content/drive/MyDrive/Trabalho/Cancer/Predição cruzada/Datasets/sist_digestorio.csv',
#                 encoding='utf-8', index=False)
